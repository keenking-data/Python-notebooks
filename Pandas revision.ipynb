# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\archive(5)\laptop_prices.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11768 entries, 0 to 11767
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brand                 11768 non-null  object
#  1   Processor             11768 non-null  object
#  2   RAM (GB)              11768 non-null  int64
#  3   Storage               11768 non-null  object
#  4   GPU                   11768 non-null  object
#  5   Screen Size (inch)    11768 non-null  float64
#  6   Resolution            11768 non-null  object
#  7   Battery Life (hours)  11768 non-null  float64
#  8   Weight (kg)           11768 non-null  float64
#  9   Operating System      11768 non-null  object
#  10  Price ($)             11768 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1011.4+ KB

# %%
df[["Brand","Price ($)"]]
# Out:
#          Brand  Price ($)
# 0        Apple    3997.07
# 1        Razer    1355.78
# 2         Asus    2673.07
# 3       Lenovo     751.17
# 4        Razer    2059.83
# ...        ...        ...
# 11763     Acer     704.82
# 11764     Asus     775.59
# 11765    Razer    2789.46
# 11766  Samsung    1067.13
# 11767  Samsung    1579.55
#
# [11768 rows x 2 columns]

# %%
df[['RAM (GB)','GPU']]
# Out:
#        RAM (GB)                 GPU
# 0            64     Nvidia GTX 1650
# 1             4     Nvidia RTX 3080
# 2            32     Nvidia RTX 3060
# 3             4     Nvidia RTX 3080
# 4             4  AMD Radeon RX 6600
# ...         ...                 ...
# 11763         4     Nvidia RTX 2060
# 11764         4  AMD Radeon RX 6800
# 11765         4  AMD Radeon RX 6600
# 11766        16          Integrated
# 11767         8     Nvidia RTX 3080
#
# [11768 rows x 2 columns]

# %%
df[df['Price ($)'] >1000]
# Out:
#          Brand    Processor  RAM (GB)    Storage                 GPU  \
# 0        Apple  AMD Ryzen 3        64  512GB SSD     Nvidia GTX 1650
# 1        Razer  AMD Ryzen 7         4    1TB SSD     Nvidia RTX 3080
# 2         Asus     Intel i5        32    2TB SSD     Nvidia RTX 3060
# 4        Razer     Intel i3         4  256GB SSD  AMD Radeon RX 6600
# 5         Acer  AMD Ryzen 3        64    2TB SSD     Nvidia RTX 3060
# ...        ...          ...       ...        ...                 ...
# 11761     Dell     Intel i3        64    1TB SSD  AMD Radeon RX 6600
# 11762    Apple  AMD Ryzen 9        16    1TB HDD  AMD Radeon RX 6600
# 11765    Razer  AMD Ryzen 9         4    2TB SSD  AMD Radeon RX 6600
# 11766  Samsung  AMD Ryzen 7        16  512GB SSD          Integrated
# 11767  Samsung     Intel i7         8  256GB SSD     Nvidia RTX 3080
#
#        Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# ...

# %%
#sorting values
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Downloads\archive(5)\laptop_prices.csv")
df.sort_values(by = 'Price ($)', ascending = False)
# Out:
#            Brand    Processor  RAM (GB)    Storage                 GPU  \
# 3790       Apple  AMD Ryzen 9        64  512GB SSD  AMD Radeon RX 6600
# 10436      Apple  AMD Ryzen 9        64  256GB SSD     Nvidia RTX 3080
# 11580      Apple  AMD Ryzen 9        64    1TB SSD  AMD Radeon RX 6800
# 7609       Apple     Intel i9        64  512GB SSD  AMD Radeon RX 6800
# 5960       Apple  AMD Ryzen 9        64    2TB SSD     Nvidia RTX 3060
# ...          ...          ...       ...        ...                 ...
# 10375       Asus  AMD Ryzen 5         4    1TB HDD          Integrated
# 2689        Acer     Intel i5         4    1TB HDD          Integrated
# 10468       Dell     Intel i3         4    1TB HDD          Integrated
# 8207        Asus  AMD Ryzen 3         4    2TB SSD          Integrated
# 11587  Microsoft     Intel i3         4    1TB HDD          Integrated
#
#        Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# ...

# %%
#dropping columns
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Downloads\archive(5)\laptop_prices.csv")
df.drop(columns=['Resolution','Screen Size (inch)','Battery Life (hours)','Weight (kg)', 'Operating System'], inplace = True)
print(df)
# Out:
#          Brand    Processor  RAM (GB)    Storage                 GPU  \
# 0        Apple  AMD Ryzen 3        64  512GB SSD     Nvidia GTX 1650
# 1        Razer  AMD Ryzen 7         4    1TB SSD     Nvidia RTX 3080
# 2         Asus     Intel i5        32    2TB SSD     Nvidia RTX 3060
# 3       Lenovo     Intel i5         4  256GB SSD     Nvidia RTX 3080
# 4        Razer     Intel i3         4  256GB SSD  AMD Radeon RX 6600
# ...        ...          ...       ...        ...                 ...
# 11763     Acer     Intel i3         4    2TB SSD     Nvidia RTX 2060
# 11764     Asus     Intel i3         4    2TB SSD  AMD Radeon RX 6800
# 11765    Razer  AMD Ryzen 9         4    2TB SSD  AMD Radeon RX 6600
# 11766  Samsung  AMD Ryzen 7        16  512GB SSD          Integrated
# 11767  Samsung     Intel i7         8  256GB SSD     Nvidia RTX 3080
#
#        Price ($)
# 0        3997.07
# 1        1355.78
# 2        2673.07
# 3         751.17
# 4        2059.83
# ...          ...
# ...

# %%
#counting and sum null values
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Downloads\archive(5)\laptop_prices.csv")
df.isnull().sum()
# Out:
# Brand                   0
# Processor               0
# RAM (GB)                0
# Storage                 0
# GPU                     0
# Screen Size (inch)      0
# Resolution              0
# Battery Life (hours)    0
# Weight (kg)             0
# Operating System        0
# Price ($)               0
# dtype: int64

# %%
#replaces null values with 0
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Downloads\archive(5)\laptop_prices.csv")
df.fillna(0, inplace=True)
print(df)
# Out:
#          Brand    Processor  RAM (GB)    Storage                 GPU  \
# 0        Apple  AMD Ryzen 3        64  512GB SSD     Nvidia GTX 1650
# 1        Razer  AMD Ryzen 7         4    1TB SSD     Nvidia RTX 3080
# 2         Asus     Intel i5        32    2TB SSD     Nvidia RTX 3060
# 3       Lenovo     Intel i5         4  256GB SSD     Nvidia RTX 3080
# 4        Razer     Intel i3         4  256GB SSD  AMD Radeon RX 6600
# ...        ...          ...       ...        ...                 ...
# 11763     Acer     Intel i3         4    2TB SSD     Nvidia RTX 2060
# 11764     Asus     Intel i3         4    2TB SSD  AMD Radeon RX 6800
# 11765    Razer  AMD Ryzen 9         4    2TB SSD  AMD Radeon RX 6600
# 11766  Samsung  AMD Ryzen 7        16  512GB SSD          Integrated
# 11767  Samsung     Intel i7         8  256GB SSD     Nvidia RTX 3080
#
#        Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# ...

# %%
#dropping null values in a data set and updating to the original dataset
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Downloads\archive(5)\laptop_prices.csv")
df.dropna(inplace=True)
print(df)
df.to_csv(r"C:\Users\user\Downloads\archive(5)\laptop_prices.csvr",index=False)
# Out:
#          Brand    Processor  RAM (GB)    Storage                 GPU  \
# 0        Apple  AMD Ryzen 3        64  512GB SSD     Nvidia GTX 1650
# 1        Razer  AMD Ryzen 7         4    1TB SSD     Nvidia RTX 3080
# 2         Asus     Intel i5        32    2TB SSD     Nvidia RTX 3060
# 3       Lenovo     Intel i5         4  256GB SSD     Nvidia RTX 3080
# 4        Razer     Intel i3         4  256GB SSD  AMD Radeon RX 6600
# ...        ...          ...       ...        ...                 ...
# 11763     Acer     Intel i3         4    2TB SSD     Nvidia RTX 2060
# 11764     Asus     Intel i3         4    2TB SSD  AMD Radeon RX 6800
# 11765    Razer  AMD Ryzen 9         4    2TB SSD  AMD Radeon RX 6600
# 11766  Samsung  AMD Ryzen 7        16  512GB SSD          Integrated
# 11767  Samsung     Intel i7         8  256GB SSD     Nvidia RTX 3080
#
#        Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# ...

# %%
#sum of values in columns
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Downloads\archive(5)\laptop_prices.csv")
def sum_columns(df):
    return df[['RAM (GB)','Price ($)']].sum()
total_sum = sum_columns(df)
print(total_sum)
# Out:
# RAM (GB)       292468.00
# Price ($)    25696270.68
# dtype: float64
